# %% [markdown]
# # EDA for our Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
url_df = pd.read_csv('fraudish_articles.csv')

# %% [markdown]
# ## Import our dataset of fraud related articles with a cosine simliarity of .60
